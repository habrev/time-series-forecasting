# %%
import os
import warnings
import sys
warnings.filterwarnings("ignore")

# %%
# Define the folder 
drive_folder = "../scripts"

# Append it to sys.path to allow importing modules
sys.path.append(os.path.abspath(drive_folder))

# %% [markdown]
# # extracting the dataset for the three datasets

# %%
from preprocess import Preprocessor
processor=Preprocessor()

# %%
# Example usage
tickers = ["TSLA", "BND", "SPY"]
processor.dload_save_yfinance_data(tickers)

import pandas as pd
stoke_data=pd.read_csv("../assets/data/stock_data.csv")
stoke_data.set_index('Date',inplace=True)
stoke_data.index=pd.to_datetime(stoke_data.index)
stoke_data.head()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#                  TSLA        BND         SPY
# Date
# 2015-01-02  14.620667  62.573124  172.592911
# 2015-01-05  14.006000  62.754799  169.475952
# 2015-01-06  14.085333  62.936520  167.879669
# 2015-01-07  14.063333  62.974339  169.971558
# 2015-01-08  14.041333  62.875961  172.987778

# %%
processor.check_missing(stoke_data)
# Out:
# <h2>There is no misssing value </h2>

# %% [markdown]
# # Closing Price Over Time

# %%
processor.timeseries_plot(stoke_data)

# %% [markdown]
# # Daily Percentage Return

# %%
processor.daily_pct_return(stoke_data)
# Out:
# TSLA summary :
# count    2473.000000
# mean        0.179905
# std         3.580220
# min       -21.062824
# 25%        -1.616758
# 50%         0.125870
# 75%         1.895455
# max        21.919035
# Name: TSLA, dtype: float64
# BND summary :
# count    2473.000000
# mean        0.006343
# std         0.342980
# min        -5.438523
# 25%        -0.151056
# 50%         0.012408
# 75%         0.172736
# max         4.220115
# Name: BND, dtype: float64
# SPY summary :
# count    2473.000000
# mean        0.055113
# std         1.113370
# min       -10.942362
# 25%        -0.370866
# 50%         0.059624
# 75%         0.593246
# max         9.060330
# Name: SPY, dtype: float64

# %%
processor.return_distribution(stoke_data)

# %% [markdown]
# # Rolling means and standard deviations

# %%
processor.rolling_mean_std(stoke_data)

# %% [markdown]
# # Outlier Detection

# %%
processor.outliers_plot(stoke_data)
# Out:
# TSLA Outliers Date : DatetimeIndex(['2021-10-25', '2021-10-26', '2021-10-27', '2021-10-28',
#                '2021-10-29', '2021-11-01', '2021-11-02', '2021-11-03',
#                '2021-11-04', '2021-11-05', '2021-11-08', '2021-11-09',
#                '2021-11-10', '2021-11-11', '2021-11-12', '2021-11-15',
#                '2021-11-16', '2021-11-17', '2021-11-18', '2021-11-19',
#                '2021-11-22', '2021-11-23', '2021-11-24', '2021-11-26',
#                '2021-11-29', '2021-11-30', '2021-12-01', '2021-12-02',
#                '2021-12-03', '2021-12-06', '2021-12-07', '2021-12-08',
#                '2021-12-09', '2021-12-10', '2021-12-22', '2021-12-23',
#                '2021-12-27', '2021-12-28', '2021-12-29', '2021-12-30',
#                '2021-12-31', '2022-01-03', '2022-01-04', '2022-01-05',
#                '2022-01-06', '2022-01-07', '2022-01-10', '2022-01-11',
#                '2022-01-12', '2022-01-13', '2022-01-14', '2022-01-18',
#                '2022-01-19', '2022-01-20', '2022-03-23', '2022-03-24',
#                '2022-03-25', '2022-03-28', '2022-03-29', '2022-03-30',
#                '2022-03-31', '2022-04-01', '2022-04-04', '2022-04-05',
#                '2022-04-06', '2022-04-07', '2022-04-08', '2022-04-13',
#                '2022-04-18', '2022-04-19', '2022-04-21', '2022-04-22',
#                '2022-04-25'],
#               dtype='datetime64[ns]', name='Date', freq=None)
# BND Outliers Date : DatetimeIndex([], dtype='datetime64[ns]', name='Date', freq=None)
# SPY Outliers Date : DatetimeIndex(['2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14',
#                '2024-06-17', '2024-06-18', '2024-06-20', '2024-06-21',
#                '2024-06-24', '2024-06-25', '2024-06-26', '2024-06-27',
#                '2024-06-28', '2024-07-01', '2024-07-02', '2024-07-03',
#                '2024-07-05', '2024-07-08', '2024-07-09', '2024-07-10',
#                '2024-07-11', '2024-07-12', '2024-07-15', '2024-07-16',
#                '2024-07-17', '2024-07-18', '2024-07-19', '2024-07-22',
#                '2024-07-23', '2024-07-24', '2024-07-25', '2024-07-26',
#                '2024-07-29', '2024-07-30', '2024-07-31', '2024-08-01',
#                '2024-08-13', '2024-08-14', '2024-08-15', '2024-08-16',
#                '2024-08-19', '2024-08-20', '2024-08-21', '2024-08-22',
#                '2024-08-23', '2024-08-26', '2024-08-27', '2024-08-28',
#                '2024-08-29', '2024-08-30', '2024-09-03', '2024-09-04',
#                '2024-09-05', '2024-09-06', '2024-09-09', '2024-09-10',
#                '2024-09-11', '2024-09-12', '2024-09-13', '2024-09-16',
#                '2024-09-17', '2024-09-18', '2024-09-19', '2024-09-20',
#                '2024-09-23', '2024-09-24', '2024-09-25', '2024-09-26',
#                '2024-09-27', '2024-09-30', '2024-10-01', '2024-10-02',
#                '2024-10-03', '2024-10-04', '2024-10-07', '2024-10-08',
#                '2024-10-09', '2024-10-10', '2024-10-11', '2024-10-14',
#                '2024-10-15', '2024-10-16', '2024-10-17', '2024-10-18',
#                '2024-10-21', '2024-10-22', '2024-10-23', '2024-10-24',
#                '2024-10-25', '2024-10-28', '2024-10-29', '2024-10-30'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %% [markdown]
# # Seasonality and Trends

# %%
processor.seasonal_decompose(stoke_data)

# %% [markdown]
# # VaR and Sharpe Ratio

# %%
processor.var_ratio(stoke_data)
# Out:
# TSLA Value at Risk (VaR) at 95% confidence: -5.125703646165556
# BND Value at Risk (VaR) at 95% confidence: -0.47976196673941596
# SPY Value at Risk (VaR) at 95% confidence: -1.676386266569705

# %%
processor.sharpe_ratio(stoke_data)
# Out:
# TSLA Sharpe Ratio: 0.04467250513528375
# BND Sharpe Ratio: -0.0398260995186155
# SPY Sharpe Ratio: 0.03154418289438107
